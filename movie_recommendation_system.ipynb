# %%
import pandas as pd
df = pd.read_csv("/content/dataset.csv")
print(df)
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# 2                                          Drama,Crime                en
# 3                                    Drama,History,War                en
# 4                                          Drama,Crime                en
# ...                                                ...               ...
# 9995                          Action,Adventure,Fantasy                en
# 9996  Action,TV Movie,Science Fiction,Comedy,Adventure                en
# 9997                        Action,Science Fiction,War                en
# 9998                    Adventure,Fantasy,Action,Drama                en
# 9999                             Thriller,Action,Crime                en
#
#                                                overview  popularity  \
# 0     Framed in the 1940s for the double murder of h...      94.075
# 1     Raj is a rich, carefree, happy-go-lucky second...      25.408
# 2     Spanning the years 1945 to 1955, a chronicle o...      90.585
# 3     The true story of how businessman Oskar Schind...      44.761
# 4     In the continuing saga of the Corleone crime f...      57.749
# ...                                                 ...         ...
# 9995  The story follows the adventures of Aang, a yo...      98.322
# 9996  The sharks take bite out of the East Coast whe...      12.490
# 9997  During World War II, a brave, patriotic Americ...      18.333
# 9998  A man named Farmer sets out to rescue his kidn...      15.159
# 9999  Seeking justice for his partner’s murder by an...      16.482
#
#      release_date  vote_average  vote_count
# 0      1994-09-23           8.7       21862
# 1      1995-10-19           8.7        3731
# 2      1972-03-14           8.7       16280
# 3      1993-12-15           8.6       12959
# 4      1974-12-20           8.6        9811
# ...           ...           ...         ...
# 9995   2010-06-30           4.7        3347
# 9996   2015-07-22           4.7         417
# 9997   1990-12-14           4.6         332
# 9998   2007-11-29           4.7         668
# 9999   2019-05-31           4.6         221
#
# [10000 rows x 9 columns]

# %%
features = df[['id','title','genre','overview']]
features
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre  \
# 0                                          Drama,Crime
# 1                                 Comedy,Drama,Romance
# 2                                          Drama,Crime
# 3                                    Drama,History,War
# 4                                          Drama,Crime
# ...                                                ...
# 9995                          Action,Adventure,Fantasy
# 9996  Action,TV Movie,Science Fiction,Comedy,Adventure
# 9997                        Action,Science Fiction,War
# 9998                    Adventure,Fantasy,Action,Drama
# 9999                             Thriller,Action,Crime
#
#                                                overview
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
# [10000 rows x 4 columns]

# %%
df['tags'] = df['overview'] + df['genre'] # define separate column called tags

# %%
#from the updated dataset, we do not need the overview and genre columns anymore
new_df = df[['id','title','tags']]
new_df
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
# [10000 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 10000, stop_words = 'english')
vector = cv.fit_transform(new_df['tags'].values.astype('U')).toarray()
print(vector.shape)
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vector)
print(similarity)
# Out:
# [[1.         0.05634362 0.12888482 ... 0.07559289 0.11065667 0.06388766]
#  [0.05634362 1.         0.07624929 ... 0.         0.03636965 0.        ]
#  [0.12888482 0.07624929 1.         ... 0.02273314 0.06655583 0.08645856]
#  ...
#  [0.07559289 0.         0.02273314 ... 1.         0.03253    0.02817181]
#  [0.11065667 0.03636965 0.06655583 ... 0.03253    1.         0.0412393 ]
#  [0.06388766 0.         0.08645856 ... 0.02817181 0.0412393  1.        ]]

# %%
index = new_df[new_df["title"] == "The Godfather"].index[0] # we access the index of a movie based on its title

# %%
# so if we access the index, we can find the similarity score of all the movies
similarity_values = sorted(list(enumerate(similarity[index])),reverse=True, key = lambda x:x[1]) #sort based on the score
print(similarity_values)
# Out:
# [(2, 1.0000000000000004), (4, 0.48976229911514363), (7419, 0.3521803625302496), (153, 0.3354968547317302), (2624, 0.3234983196103152), (9520, 0.3112864031823452), (2412, 0.3081578172139684), (330, 0.30499714066520933), (5010, 0.2995012465378748), (779, 0.29606845410646954), (7049, 0.29606845410646954), (9362, 0.2934836354418746), (4569, 0.29261523994305977), (3670, 0.2893456933022473), (4872, 0.28934569330224724), (1816, 0.2857953049377246), (4811, 0.28529870107872785), (6964, 0.2803652103289399), (4380, 0.2798845714165278), (734, 0.2758802939230217), (5605, 0.2758802939230217), (1223, 0.2756247308353552), (6788, 0.2756247308353552), (9245, 0.2756247308353552), (8555, 0.2744974265986884), (709, 0.2727977357881894), (3742, 0.2686124597780274), (519, 0.26687249808205815), (821, 0.26687249808205815), (6565, 0.26687249808205815), (250, 0.26622333025588873), (8503, 0.26622333025588873), (747, 0.2652335521937267), (233, 0.2641352718976872), (2272, 0.2641352718976872), (7866, 0.25890435250935817), (263, 0.25438520029955736), (1540, 0.25438520029955736), (2229, 0.2537729606626882), (6587, 0.25160980414135636), (4712, 0.2516098041413563), (7280, 0.2516098041413563), (7318, 0.2516098041413563), (945, 0.25058072087536704), (8341, 0.24650596604914954), (5632, 0.2465059660491495), (1926, 0.2448989999894618), (3235, 0.2448989999894618), (4496, 0.2448989999894618), (5290, 0.2448989999894618), (5954, 0.24454174378176674), (1209, 0.2445417437817667), (2587, 0.2445417437817667), (8211, 0.2445417437817667), (951, 0.24399771253216748), (1039, 0.24399771253216748), (892, 0.24238714897403307), (1343, 0.24112141108520607), (1447, 0.24112141108520607), (6308, 0.24112141108520607), (838, 0.23869801881466574), (4056, 0.23869801881466574), (135, 0.23816275411477045), (1411, 0.23624976928744731), (7356, 0.23624976928744731), (434, 0.23531040266750586), (3507, 0.23294541397390264), (3548, 0.23294541397390264), (3927, 0.23294541397390264), (1133, 0.230556167081694), (5367, 0.22990024493585143), (4491, 0.22874785549890703), (5517, 0.22874785549890703), (6683, 0.22874785549890703), (8086, 0.22874785549890703), (1488, 0.228747855498907), (2059, 0.228747855498907), (2174, 0.228747855498907), (5331, 0.228747855498907), (6070, 0.228747855498907), (8570, 0.2282766956670531), (748, 0.22758963106682426), (1611, 0.22758963106682426), (3611, 0.22758963106682426), (8771, 0.22758963106682426), (7071, 0.2265461887154396), (495, 0.22563549475375508), (4127, 0.22563549475375508), (26, 0.22191801643659276), (2115, 0.22191801643659276), (7207, 0.22191801643659276), (3704, 0.22191801643659273), (5559, 0.22191801643659273), (5836, 0.22191801643659273), (36, 0.220112726581406), (1201, 0.220112726581406), (1216, 0.220112726581406), (1773, 0.220112726581406), (3054, 0.220112726581406), (3126, 0.220112726581406), (3848, 0.220112726581406), (1918, 0.21977383072747694), (9212, 0.2191164142659107), (5502, 0.2179004822276417), (634, 0.21790048222764163), (1331, 0.21790048222764163), (1755, 0.21700926997668546), (7783, 0.21566554640687685), (8984, 0.21566554640687685), (5189, 0.21566554640687682), (4064, 0.21418329140997422), (1617, 0.21349799846564654), (1834, 0.21349799846564654), (4885, 0.21349799846564654), (5965, 0.21349799846564654), (7910, 0.21349799846564654), (1629, 0.21237274928075958), (58, 0.2114774672189068), (794, 0.2114774672189068), (1362, 0.2114774672189068), (1729, 0.2114774672189068), (3142, 0.2114774672189068), (4170, 0.2114774672189068), (4446, 0.2114774672189068), (5420, 0.2114774672189068), (2717, 0.21147746721890678), (956, 0.20991342856239584), (1823, 0.20991342856239584), (2827, 0.20991342856239584), (3368, 0.20991342856239584), (4360, 0.20991342856239584), (4707, 0.20991342856239584), (4860, 0.20991342856239584), (4967, 0.20991342856239584), (8075, 0.20991342856239584), (8632, 0.20991342856239584), (7816, 0.20935201159410272), (3042, 0.20922631238637657), (3390, 0.20621570489058683), (1171, 0.2062157048905868), (1496, 0.20543854480931223), (3550, 0.205438544 ...

# %%
# so we'll access the top 5 movies
for value in similarity_values[:5]:
  print(value, new_df.iloc[value[0]].title) # get the top movies and print them
# Out:
# (2, 1.0000000000000004) The Godfather
# (4, 0.48976229911514363) The Godfather: Part II
# (7419, 0.3521803625302496) Blood Ties
# (153, 0.3354968547317302) Joker
# (2624, 0.3234983196103152) Bomb City

# %%
def recommend(movie): # so this will do the recommendation of the top 5 movies, can be leveraged based on the needs
  index = new_df[new_df["title"] == movie].index[0]
  similarity_values = sorted(list(enumerate(similarity[index])),reverse=True, key = lambda x:x[1])
  for value in similarity_values[:5]:
    print(new_df.iloc[value[0]].title)
recommend("Joker")
# Out:
# Joker
# Blood Ties
# The Big Heat
# Dead Man Down
# Chopper

# %%
# pickle the files for later uses like web dev
import pickle
pickle.dump(new_df, open("/content/movies.pkl","wb"))

# %%
pickle.dump(similarity, open("/content/similarity.pkl","wb"))

# %%
#read the pickle files
pickle.load(open("/content/movies.pkl","rb"))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# 3     The true story of how businessman Oskar Schind...
# 4     In the continuing saga of the Corleone crime f...
# ...                                                 ...
# 9995  The story follows the adventures of Aang, a yo...
# 9996  The sharks take bite out of the East Coast whe...
# 9997  During World War II, a brave, patriotic Americ...
# 9998  A man named Farmer sets out to rescue his kidn...
# 9999  Seeking justice for his partner’s murder by an...
#
# [10000 rows x 3 columns]
